# %%
# First Solution - Brute Force
class Solution:
    def twoSum(self, nums: list[int], target: int) -> list[int]:
        n = len(nums)
        for i in range(n):
            for j in range(i + 1, n):
                if nums[i] + nums[j] == target:
                    return [i, j]

# %%
class Solution:
    def twoSum(self, nums: list[int], target: int) -> list[int]:
        nums_new = []
        index = []
        target_new = target - min(nums)
        for i in range(len(nums)):
            if nums[i] <= target_new:
                for j in nums_new:
                    if nums_new[j] + nums[i] == target:
                        return [index[i], i]
                nums_new.append(nums[i])
                index.append(i)
        print(nums_new)
        n = len(nums_new)
        for i in range(n):
            for j in range(i + 1, n):
                if nums_new[i] + nums_new[j] == target:
                    return [index[i], index[j]]

# %%
class Solution:
    def twoSum(self, nums: list[int], target: int) -> list[int]:
        nums_new = []
        index = []
        target_new = target - min(nums)
        for i in range(len(nums)):
            if nums[i] <= target_new:
                nums_new.append(nums[i])
                index.append(i)
        print(nums_new)
        n = len(nums_new)
        for i in range(n):
            for j in range(i + 1, n):
                if nums_new[i] + nums_new[j] == target:
                    return [index[i], index[j]]

# %%
class Solution:
    def twoSum(self, nums: list[int], target: int) -> list[int]:
        nums_new = []
        index = []
        target_new = target - min(nums)
        for i in range(len(nums)):
            if nums[i] <= target_new:
                for j in range(len(nums_new)):
                    if nums[i] + nums_new[j] == target:
                        return [index[j], i]
                nums_new.append(nums[i])
                index.append(i)

# %%
#hash table
class Solution:
    def twoSum(self, nums: list[int], target: int) -> list[int]:
        d = {}
        for i in range(len(nums)):
            d[nums[i]] = i
        for j in range(len(nums)):
            second = target - nums[j]
            if second in d and d[second] != j:
                return [j, d[second]]

# %%
result = Solution()
# Example 1:

nums = [2,7,11,15]
target = 9
#Output: [0,1]
#Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
print(result.twoSum(nums, target))


#Example 2:

nums = [3,2,4]
target = 6
#Output: [1,2]
print(result.twoSum(nums, target))

#Example 3:

nums = [3,3]
target = 6
#Output: [0,1]
print(result.twoSum(nums, target))

nums = [-3,4,3,90]
target = 0
#Output: [0,2]
print(result.twoSum(nums, target))

nums = [3,2,4]
target = 6
#Output: [1,2]
print(result.twoSum(nums, target))
# Out:
# [0, 1]
# [1, 2]
# [0, 1]
# [0, 2]
# [1, 2]
